# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')

data
# Out:
#      image_name  sigma  noise_psnr  noise_ssim  denoise_psnr_lpg_pca  \
# 0       barbara     10   28.130804    0.859047             28.378792
# 1       barbara     20   22.110204    0.640805             26.929008
# 2       barbara     30   18.588379    0.476335             25.680209
# 3       barbara     40   16.089604    0.362455             24.522022
# 4          boat     10   28.130804    0.850411             26.752841
# 5          boat     20   22.110204    0.624392             25.652378
# 6          boat     30   18.588379    0.460097             24.633464
# 7          boat     40   16.089604    0.349275             23.677603
# 8     cameraman     10   28.130804    0.806454             27.257002
# 9     cameraman     20   22.110204    0.556364             26.199940
# 10    cameraman     30   18.588379    0.400526             25.174639
# 11    cameraman     40   16.089604    0.304976             24.162341
# 12       couple     10   28.130804    0.862428             26.837782
# ...

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
# plt.plot(data['noise_psnr'], label='noise')
plt.plot(data['denoise_psnr_lpg_pca'], label='LPG-PCA')
# plt.plot(data['denoise_psnr_mf'], label='Median')
plt.plot(data['denoise_psnr_nlm'], label='NLM')
plt.plot(data['denoise_psnr_bm3d'], label='BM3D')
plt.title('PSNR')

plt.legend()

plt.subplot(1, 2, 2)
# plt.plot(data['noise_ssim'], label='noise')
plt.plot(data['denoise_ssim_lpg_pca'], label='LPG-PCA')
# plt.plot(data['denoise_ssim_mf'], label='Median')
plt.plot(data['denoise_ssim_nlm'], label='NLM')
plt.plot(data['denoise_ssim_bm3d'], label='BM3D')
plt.title('SSIM')

plt.legend()

plt.show()
